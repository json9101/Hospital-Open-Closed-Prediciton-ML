# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
hospital_data=pd.read_csv("C:/Users/eagls/bootcamp/프로젝트/train.csv")
hospital_data_df = pd.DataFrame(hospital_data)

# %%
hospital_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 58 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   inst_id             301 non-null    int64
#  1   OC                  301 non-null    object
#  2   sido                301 non-null    object
#  3   sgg                 301 non-null    int64
#  4   openDate            301 non-null    int64
#  5   bedCount            296 non-null    float64
#  6   instkind            300 non-null    object
#  7   revenue1            293 non-null    float64
#  8   salescost1          293 non-null    float64
#  9   sga1                293 non-null    float64
#  10  salary1             293 non-null    float64
#  11  noi1                293 non-null    float64
#  12  noe1                293 non-null    float64
#  13  interest1           293 non-null    float64
#  14  ctax1               293 non-null    float64
# ...

# %%
hospital_data_df.drop_duplicates()
# Out:
#      inst_id      OC       sido  sgg  openDate  bedCount  \
# 0          1    open  choongnam   73  20071228     175.0
# 1          3    open  gyeongnam   32  19970401     410.0
# 2          4    open   gyeonggi   89  20161228     468.0
# 3          7    open    incheon  141  20000814     353.0
# 4          9    open  gyeongnam   32  20050901     196.0
# ..       ...     ...        ...  ...       ...       ...
# 296      422    open    jeonnam  178  20050211     214.0
# 297      423   close  choongnam  159  20140618       NaN
# 298      426   close  gyeongbuk  107  19830705       NaN
# 299      427   close   gyeonggi  169  20070101     180.0
# 300      428    open      seoul   79  20011017       NaN
#
#                  instkind      revenue1    salescost1          sga1  ...  \
# 0        nursing_hospital  4.217530e+09  0.000000e+00  3.961135e+09  ...
# 1        general_hospital           NaN           NaN           NaN  ...
# ...

# %%
hospital_data_df1 = hospital_data_df.copy()

# %%
hospital_data_df1.drop(hospital_data_df1[hospital_data_df1['inst_id']==3].index,inplace=True)
hospital_data_df1.drop(hospital_data_df1[hospital_data_df1['inst_id']==26].index,inplace=True)
hospital_data_df1.drop(hospital_data_df1[hospital_data_df1['inst_id']==55].index,inplace=True)
hospital_data_df1.drop(hospital_data_df1[hospital_data_df1['inst_id']==94].index,inplace=True)
hospital_data_df1.drop(hospital_data_df1[hospital_data_df1['inst_id']==353].index,inplace=True)
hospital_data_df1.drop(hospital_data_df1[hospital_data_df1['inst_id']==362].index,inplace=True)
hospital_data_df1.drop(hospital_data_df1[hospital_data_df1['inst_id']==363].index,inplace=True)

# %%
hospital_data_df1.shape
# Out:
# (294, 58)

# %%
hospital_data_df1.isnull().sum()
# Out:
# inst_id                0
# OC                     0
# sido                   0
# sgg                    0
# openDate               0
# bedCount               5
# instkind               1
# revenue1               1
# salescost1             1
# sga1                   1
# salary1                1
# noi1                   1
# noe1                   1
# interest1              1
# ctax1                  1
# profit1                1
# liquidAsset1           1
# quickAsset1            1
# receivableS1           1
# inventoryAsset1        1
# nonCAsset1             1
# tanAsset1              1
# OnonCAsset1            1
# receivableL1           1
# debt1                  1
# liquidLiabilities1     1
# shortLoan1             1
# NCLiabilities1         1
# longLoan1              1
# netAsset1              1
# surplus1               1
# revenue2               1
# salescost2             1
# sga2                   1
# salary2                1
# noi2                   1
# noe2                   1
# ...

# %%
hospital_data_df1=pd.get_dummies(hospital_data_df1,columns=['instkind'])

# %%
hospital_data_df1['OC'] = hospital_data_df1['OC'].map({'open': 0, ' close':1})

# %%
hospital_data_df1['ownerChange'] = hospital_data_df1['ownerChange'].map({'same': 0, 'change': 1})

# %%
hospital_data_df1.head()
# Out:
#    inst_id  OC       sido  sgg  openDate  bedCount      revenue1  \
# 0        1   0  choongnam   73  20071228     175.0  4.217530e+09
# 2        4   0   gyeonggi   89  20161228     468.0  1.004522e+09
# 3        7   0    incheon  141  20000814     353.0  7.250734e+10
# 4        9   0  gyeongnam   32  20050901     196.0  4.904354e+10
# 5       11   0  gyeongnam  155  20020501     243.0  3.358054e+10
#
#      salescost1          sga1       salary1  ...  employee1  employee2  \
# 0  0.000000e+00  3.961135e+09  2.033835e+09  ...       62.0       64.0
# 2  5.154837e+08  4.472197e+08  2.964023e+08  ...      234.0        1.0
# 3  0.000000e+00  7.067740e+10  3.178605e+10  ...      663.0      663.0
# 4  0.000000e+00  4.765605e+10  2.446078e+10  ...      206.0      197.0
# 5  9.222997e+09  2.372791e+10  1.665533e+10  ...      397.0      390.0
#
#    ownerChange  instkind_clinic  instkind_dental_clinic  \
# 0          0.0                0                       0
# ...

# %%
hospital_data_df1['bedCount'].fillna(-1,inplace=True)

# %%
hospital_data_df1['ownerChange'].fillna(-1,inplace=True)

# %%
hospital_data_df1
# Out:
#      inst_id  OC       sido  sgg  openDate  bedCount      revenue1  \
# 0          1   0  choongnam   73  20071228     175.0  4.217530e+09
# 2          4   0   gyeonggi   89  20161228     468.0  1.004522e+09
# 3          7   0    incheon  141  20000814     353.0  7.250734e+10
# 4          9   0  gyeongnam   32  20050901     196.0  4.904354e+10
# 5         11   0  gyeongnam  155  20020501     243.0  3.358054e+10
# ..       ...  ..        ...  ...       ...       ...           ...
# 296      422   0    jeonnam  178  20050211     214.0  7.614697e+09
# 297      423   1  choongnam  159  20140618      -1.0  6.717144e+09
# 298      426   1  gyeongbuk  107  19830705      -1.0  0.000000e+00
# 299      427   1   gyeonggi  169  20070101     180.0  2.116892e+09
# 300      428   0      seoul   79  20011017      -1.0  1.340971e+09
#
#        salescost1          sga1       salary1  ...  employee1  employee2  \
# 0    0.000000e+00  3.961135e+09  2.033835e+09  ...       62.0       64.0
# ...
